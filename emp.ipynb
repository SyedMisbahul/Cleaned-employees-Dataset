# %%
import pandas as pd

# %%
emp = pd.read_csv('employees.csv')

# %%
emp.head()
# Out:
#   First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male   8/6/1993        12:42 PM   97308    6.945
# 1     Thomas    Male  3/31/1996         6:53 AM   61933    4.170
# 2      Maria  Female  4/23/1993        11:17 AM  130590   11.858
# 3      Jerry    Male   3/4/2005         1:00 PM  138705    9.340
# 4      Larry    Male  1/24/1998         4:47 PM  101004    1.389
#
#   Senior Management             Team
# 0              True        Marketing
# 1              True              NaN
# 2             False          Finance
# 3              True          Finance
# 4              True  Client Services

# %%
emp.shape
# Out:
# (1000, 8)

# %%
emp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   First Name         933 non-null    object
#  1   Gender             855 non-null    object
#  2   Start Date         1000 non-null   object
#  3   Last Login Time    1000 non-null   object
#  4   Salary             1000 non-null   int64
#  5   Bonus %            1000 non-null   float64
#  6   Senior Management  933 non-null    object
#  7   Team               957 non-null    object
# dtypes: float64(1), int64(1), object(6)
# memory usage: 62.6+ KB

# %%
emp['First Name'].unique()
# Out:
# array(['Douglas', 'Thomas', 'Maria', 'Jerry', 'Larry', 'Dennis', 'Ruby',
#        nan, 'Angela', 'Frances', 'Louise', 'Julie', 'Brandon', 'Gary',
#        'Kimberly', 'Lillian', 'Jeremy', 'Shawn', 'Diana', 'Donna', 'Lois',
#        'Matthew', 'Joshua', 'John', 'Craig', 'Scott', 'Terry', 'Benjamin',
#        'Christina', 'Joyce', 'Jean', 'Theresa', 'Rachel', 'Linda',
#        'Stephanie', 'Michael', 'Christine', 'Beverly', 'Marilyn',
#        'Cynthia', 'Roger', 'Bruce', 'Kathy', 'Clarence', 'Chris', 'Nancy',
#        'Todd', 'Alan', 'Sara', 'Karen', 'Carl', 'Henry', 'Irene', 'Paula',
#        'Denise', 'Kathleen', 'Steve', 'Jose', 'Johnny', 'Bobby', 'Bonnie',
#        'Margaret', 'Charles', 'Robin', 'Gerald', 'Christopher', 'Steven',
#        'Doris', 'Annie', 'Janice', 'James', 'Virginia', 'Harry',
#        'Heather', 'Laura', 'Tina', 'Harold', 'Melissa', 'Aaron', 'Jack',
#        'Phyllis', 'Paul', 'Russell', 'Shirley', 'Willie', 'Ashley',
# ...

# %%
emp['Gender'].unique()
# Out:
# array(['Male', 'Female', nan], dtype=object)

# %%
emp['Start Date'].unique()
# Out:
# array(['8/6/1993', '3/31/1996', '4/23/1993', '3/4/2005', '1/24/1998',
#        '4/18/1987', '8/17/1987', '7/20/2015', '11/22/2005', '8/8/2002',
#        '8/12/1980', '10/26/1997', '12/1/1980', '1/27/2008', '1/14/1999',
#        '6/5/2016', '9/21/2010', '12/7/1986', '10/23/1981', '7/22/2010',
#        '4/22/1995', '9/5/1995', '3/8/2012', '6/14/2012', '7/1/1992',
#        '10/8/2012', '2/27/2000', '7/11/1991', '11/27/1981', '1/26/2005',
#        '8/6/2002', '2/20/2005', '8/21/1998', '12/18/1993', '1/10/2004',
#        '10/10/2006', '2/16/2009', '10/19/1981', '9/13/1986', '1/29/2016',
#        '10/10/2008', '6/28/2015', '9/9/1998', '12/7/1980', '11/16/1988',
#        '4/17/1980', '11/28/2009', '6/22/2005', '3/26/1996', '1/24/1980',
#        '9/23/2000', '12/17/2011', '2/18/1990', '3/3/2014', '8/15/2007',
#        '11/30/1999', '5/3/2006', '6/26/1996', '4/11/2010', '5/7/1997',
#        '11/23/2005', '11/6/2001', '6/12/2007', '1/2/2013', '4/11/1990',
# ...

# %%
emp['Last Login Time'].unique()
# Out:
# array(['12:42 PM', '6:53 AM', '11:17 AM', '1:00 PM', '4:47 PM', '1:35 AM',
#        '4:20 PM', '10:43 AM', '6:29 AM', '6:51 AM', '9:01 AM', '3:19 PM',
#        '1:08 AM', '11:40 PM', '7:13 AM', '6:09 AM', '5:56 AM', '7:45 PM',
#        '10:27 AM', '3:48 AM', '7:18 PM', '2:12 AM', '1:58 AM', '4:19 PM',
#        '10:08 PM', '1:12 AM', '7:45 AM', '6:58 PM', '6:30 PM', '10:06 PM',
#        '1:19 PM', '2:40 PM', '2:27 PM', '9:07 AM', '12:56 PM', '8:47 PM',
#        '8:49 PM', '1:52 AM', '2:33 AM', '11:25 AM', '8:26 PM', '3:16 AM',
#        '6:54 PM', '11:32 AM', '10:47 PM', '4:51 AM', '5:57 AM',
#        '12:13 PM', '8:05 AM', '8:29 AM', '2:41 AM', '1:28 PM', '9:23 AM',
#        '7:46 AM', '5:55 PM', '1:44 AM', '7:18 AM', '9:32 AM', '2:01 PM',
#        '12:03 PM', '5:25 PM', '10:33 PM', '6:46 PM', '11:44 PM',
#        '11:57 PM', '1:39 PM', '4:31 PM', '2:26 PM', '4:23 PM', '10:01 AM',
#        '2:24 PM', '1:27 AM', '8:13 PM', '3:15 PM', '3:30 PM', '12:50 AM',
# ...

# %%
emp['Salary'].unique()
# Out:
# array([ 97308,  61933, 130590, 138705, 101004, 115163,  65476,  45906,
#         95570, 139852,  63241, 102508, 112807, 109831,  41426,  59414,
#         90370, 111737, 132940,  81014,  64714, 100612,  90816, 125792,
#         97950,  37076,  37598, 122367, 124008,  79529, 118780,  88657,
#        122340, 119082,  95734,  85182, 142032,  57427,  36844, 122173,
#         99283,  66582, 121918,  73524, 145146,  88010, 114796,  66820,
#         93581, 113590,  94976,  41126,  49339,  40341,  83677, 102488,
#        130276,  64715,  72670,  66851,  48866, 106862,  58112,  35203,
#         77834,  61310, 125250,  51178,  84834, 100863,  84692, 118172,
#         54043,  90582,  62096, 104897, 131604, 107391, 114797, 115814,
#        137126,  47369,  35095, 148115,  83072, 100238, 103495, 144887,
#         64088,  51082,  91719, 128771, 119009, 111858, 130620,  43026,
#        142321, 140371, 100705,  77544,  48109,  61602, 103902, 136984,
# ...

# %%
emp['Bonus %'].unique()
# Out:
# array([ 6.945,  4.17 , 11.858,  9.34 ,  1.389, 10.125, 10.012, 11.598,
#        18.523,  7.524, 15.132, 12.637, 17.492,  5.831, 14.543,  1.256,
#         7.369,  6.414, 19.082,  1.894,  4.934, 13.645, 18.816,  5.042,
#        13.873, 18.576,  7.757,  5.218, 13.464,  7.008,  9.096, 12.752,
#         6.417, 16.18 , 19.096, 16.675, 12.599,  9.557,  5.574,  7.797,
#         2.665, 11.308, 15.835,  5.207,  7.482, 13.886,  6.796,  9.   ,
#         6.083,  3.055, 13.83 , 14.009,  1.695, 17.578,  8.999, 17.653,
#        16.084, 15.107,  1.481, 11.279,  4.271,  3.699, 19.414, 18.04 ,
#        18.771, 12.428,  2.672,  9.735, 14.33 ,  4.382,  6.617, 16.194,
#         3.833,  4.709, 17.029,  5.118,  7.353,  1.26 ,  5.965,  4.99 ,
#        15.602, 14.822,  8.379,  6.539,  7.511,  3.887, 17.29 ,  8.276,
#         6.155, 11.955, 11.583,  8.309, 12.506,  1.601,  7.03 , 14.166,
#         1.737, 10.62 , 16.961, 12.447, 14.995, 11.849, 12.159,  8.932,
# ...

# %%
emp['Senior Management'].unique()
# Out:
# array([True, False, nan], dtype=object)

# %%
emp['Team'].unique()
# Out:
# array(['Marketing', nan, 'Finance', 'Client Services', 'Legal', 'Product',
#        'Engineering', 'Business Development', 'Human Resources', 'Sales',
#        'Distribution'], dtype=object)

# %%
backup = emp.copy()

# %%
emp[emp['First Name'].isna()]
# Out:
#     First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 7          NaN  Female  7/20/2015        10:43 AM   45906   11.598
# 23         NaN    Male  6/14/2012         4:19 PM  125792    5.042
# 25         NaN    Male  10/8/2012         1:12 AM   37076   18.576
# 32         NaN    Male  8/21/1998         2:27 PM  122340    6.417
# 39         NaN    Male  1/29/2016         2:33 AM  122173    7.797
# ..         ...     ...        ...             ...     ...      ...
# 902        NaN    Male  5/23/2001         7:52 PM  103877    6.322
# 925        NaN  Female  8/23/2000         4:19 PM   95866   19.388
# 946        NaN  Female  9/15/1985         1:50 AM  133472   16.941
# 947        NaN    Male  7/30/2012         3:07 PM  107351    5.329
# 951        NaN  Female  9/14/2010         5:19 AM  143638    9.662
#
#     Senior Management             Team
# 7                 NaN          Finance
# 23                NaN              NaN
# 25                NaN  Client Services
# ...

# %%
emp[~emp['First Name'].isna()]
# Out:
#     First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male    8/6/1993        12:42 PM   97308    6.945
# 1       Thomas    Male   3/31/1996         6:53 AM   61933    4.170
# 2        Maria  Female   4/23/1993        11:17 AM  130590   11.858
# 3        Jerry    Male    3/4/2005         1:00 PM  138705    9.340
# 4        Larry    Male   1/24/1998         4:47 PM  101004    1.389
# ..         ...     ...         ...             ...     ...      ...
# 995      Henry     NaN  11/23/2014         6:09 AM  132483   16.655
# 996    Phillip    Male   1/31/1984         6:30 AM   42392   19.675
# 997    Russell    Male   5/20/2013        12:39 PM   96914    1.421
# 998      Larry    Male   4/20/2013         4:45 PM   60500   11.985
# 999     Albert    Male   5/15/2012         6:24 PM  129949   10.169
#
#     Senior Management                  Team
# 0                True             Marketing
# 1                True                   NaN
# ...

# %%
emp = emp[~emp['First Name'].isna()]

# %%
emp = emp[~emp['Gender'].isna()]

# %%
emp[emp['Start Date'].isna()]
# Out:
# Empty DataFrame
# Columns: [First Name, Gender, Start Date, Last Login Time, Salary, Bonus %, Senior Management, Team]
# Index: []

# %%
emp = emp[~emp['Team'].isna()]

# %%
emp['Team'].unique()
# Out:
# array(['Marketing', 'Finance', 'Client Services', 'Legal', 'Product',
#        'Engineering', 'Business Development', 'Human Resources', 'Sales',
#        'Distribution'], dtype=object)

# %%
emp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 764 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   First Name         764 non-null    object
#  1   Gender             764 non-null    object
#  2   Start Date         764 non-null    object
#  3   Last Login Time    764 non-null    object
#  4   Salary             764 non-null    int64
#  5   Bonus %            764 non-null    float64
#  6   Senior Management  764 non-null    object
#  7   Team               764 non-null    object
# dtypes: float64(1), int64(1), object(6)
# memory usage: 53.7+ KB

# %%
emp['First Name'] = emp['First Name'].astype('string')

# %%
emp['Gender'] = emp['Gender'].astype('category')

# %%
emp['Start Date'] = pd.to_datetime(emp['Start Date'], errors='coerce')  # 'coerce' handles invalid dates

# %%
emp['Last Login Time'].head(10)
# Out:
# 0    2025-11-02 12:42:00
# 2    2025-11-02 11:17:00
# 3    2025-11-02 13:00:00
# 4    2025-11-02 16:47:00
# 5    2025-11-02 01:35:00
# 6    2025-11-02 16:20:00
# 8    2025-11-02 06:29:00
# 9    2025-11-02 06:51:00
# 11   2025-11-02 15:19:00
# 12   2025-11-02 01:08:00
# Name: Last Login Time, dtype: datetime64[ns]

# %%
emp['Last Login Time'] = pd.to_datetime(emp['Last Login Time'],format='%Y-%m-%d %H:%M:%S',errors='coerce')

# %%
emp['Senior Management'] = emp['Senior Management'].astype('bool')

# %%
emp['Team'] = emp['Team'].astype('category')

# %%
emp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 764 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   First Name         764 non-null    string
#  1   Gender             764 non-null    category
#  2   Start Date         764 non-null    datetime64[ns]
#  3   Last Login Time    764 non-null    datetime64[ns]
#  4   Salary             764 non-null    int64
#  5   Bonus %            764 non-null    float64
#  6   Senior Management  764 non-null    bool
#  7   Team               764 non-null    category
# dtypes: bool(1), category(2), datetime64[ns](2), float64(1), int64(1), string(1)
# memory usage: 38.5 KB

# %%
emp = emp.reset_index(drop = True)

# %%
emp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 764 entries, 0 to 763
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   First Name         764 non-null    string
#  1   Gender             764 non-null    category
#  2   Start Date         764 non-null    datetime64[ns]
#  3   Last Login Time    764 non-null    datetime64[ns]
#  4   Salary             764 non-null    int64
#  5   Bonus %            764 non-null    float64
#  6   Senior Management  764 non-null    bool
#  7   Team               764 non-null    category
# dtypes: bool(1), category(2), datetime64[ns](2), float64(1), int64(1), string(1)
# memory usage: 32.7 KB

# %%
emp.describe()
# Out:
#                           Start Date                Last Login Time  \
# count                            764                            764
# mean   1999-03-10 06:30:09.424083712  2025-11-02 11:47:42.015706624
# min              1980-01-19 00:00:00            2025-11-02 00:01:00
# 25%              1990-12-03 12:00:00            2025-11-02 05:56:45
# 50%              1999-11-14 00:00:00            2025-11-02 11:48:00
# 75%              2008-01-29 18:00:00            2025-11-02 17:48:30
# max              2016-06-16 00:00:00            2025-11-02 23:57:00
# std                              NaN                            NaN
#
#               Salary     Bonus %
# count     764.000000  764.000000
# mean    90433.196335   10.148041
# min     35013.000000    1.015000
# 25%     62071.750000    5.193250
# 50%     90428.000000    9.658500
# 75%    118075.250000   14.965000
# max    149908.000000   19.944000
# std     32864.665282    5.608733

# %%
emp['Start Date'].sort_values().head(5)
# Out:
# 723   1980-01-19
# 665   1980-01-28
# 207   1980-02-20
# 421   1980-02-25
# 612   1980-03-08
# Name: Start Date, dtype: datetime64[ns]

# %%
emp.head()
# Out:
#   First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male 1993-08-06 